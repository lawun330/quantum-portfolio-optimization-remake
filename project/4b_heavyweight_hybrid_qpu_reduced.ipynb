# %% [markdown]
# # Heavyweight Hybrid: IBM Real Quantum Hardware
#
# This notebook implements the **Heavyweight Hybrid** approach to reduced portfolio optimization using **IBM real quantum hardware (QPU)**.
#
# - **Problem Size**: 10 bonds (reduced from 31)
# - **Ansatz**: TwoLocal with full entanglement + Local Search post-processing
# - **Parameters**: Low reps (1-2) + Local Search optimization
# - **Quantum Measurements**: 512 shots per epoch
# - **Quantum Epochs**: 2 epochs of CVaR-VQE
# - **Local Search Epochs**: 8 epochs of classical refinement
# - **CVaR Parameter**: α = 0.1 (focuses on worst 10% of measurements)
# - **Hardware**: IBM real quantum device

# %% [markdown]
# ## Setup and Imports

# %%
import os
import sys
import time
import numpy as np
import pickle
from pathlib import Path
from dataclasses import asdict
import docplex.mp.model_reader
import json

# add root directory to path
ROOT = Path(os.getcwd()).parent
sys.path.append(str(ROOT))

# quantum imports
from qiskit_ibm_runtime import QiskitRuntimeService
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager

# project imports
# 1. LP/QUBO processing
from src.sbo.src.utils.lp_utils import load_quadratic_program
from src.sbo.src._problems.substitute_variables import substitute_variables
from src.sbo.src._converters.quadratic_program_to_qubo import QuadraticProgramToQubo
# 2. ansatz building
from src.step_1 import build_ansatz
# 3. quantum optimization
from src.sbo.src.patterns.building_blocks.step_3 import HardwareExecutor
# 4. local search
from src.step_1 import model_to_obj # same as importing model_to_obj_sparse_numba
from src.sbo.src.optimizer.local_search import repeated_local_search_general
# 5. experiment saving
from src.experiment import Experiment

print(f"Working directory: {ROOT}")
print(f"Python path includes: {str(ROOT)} in sys.path")
# Out:
# Working directory: C:\Users\ASUS\Downloads\WISER_Optimization_VG-main
# Python path includes: C:\Users\ASUS\Downloads\WISER_Optimization_VG-main in sys.path

# %% [markdown]
# ## Problem Setup: 31-Bond Portfolio Optimization
#
# The problem starts as an LP file, which is converted into a quadratic function and then transformed into a Quadratic Unconstrained Binary Optimization (QUBO) problem using predefined modules.

# %%
# load the 31-bond problem
lp_file_path = str(ROOT) + '/data/1/31bonds/docplex-bin-avgonly-nocplexvars.lp'

# convert LP file into quadratic problem
quadratic_problem = load_quadratic_program(lp_file_path)

# convert quadratic program into QUBO
converter = QuadraticProgramToQubo()
qubo = converter.convert(quadratic_problem)

print(f"31-bond problem: {quadratic_problem.get_num_binary_vars()} binary variables")
print(f"QUBO variables: {qubo.get_num_vars()}")
print(f"QUBO objective sense: {qubo.objective.sense}")
print(f"QUBO constant term: {qubo.objective.constant}")
# Out:
# 31-bond problem: 31 binary variables
# QUBO variables: 31
# QUBO objective sense: ObjSense.MINIMIZE
# QUBO constant term: 0.0

# %% [markdown]
# ## Problem Size Reduction
#
# Due to IBM Quantum's free tier limitations (10 minutes of QPU access per month as of 2025), the problem size is reduced to make it feasible for execution on real quantum hardware. The `substitute_variables()` function assigns a constant value of 0 to a range of variables out of 31 total variables. This effectively reduces the problem dimensionality while maintaining the optimization structure.
#
# In this implementation, 10 bonds are kept for demonstration purposes; however, this number is configurable via the `NUM_BONDS_TO_KEEP` parameter and can be adjusted based on available computational resources and desired problem complexity.
#
# - **Original Problem**: 31 bonds (31 qubits required)
# - **Reduced Problem**: 10 bonds (10 qubits required)

# %%
# set the number of bonds to keep
NUM_BONDS_TO_KEEP = 10  # -- MODIFY HERE --

# get all variable names
var_names = [var.name for var in quadratic_problem.variables]
total_vars = len(var_names)
print(f"Total variables: {total_vars}")
print()
print(f"Keeping first {NUM_BONDS_TO_KEEP}: {var_names[:NUM_BONDS_TO_KEEP]}")
print()
print(f"Discarding remaining {total_vars - NUM_BONDS_TO_KEEP}: {var_names[NUM_BONDS_TO_KEEP:]}")
print()

# reduce problem size by fixing unused variables to 0
constants = {var_names[i]: 0 for i in range(NUM_BONDS_TO_KEEP, total_vars)}
smaller_quadratic_problem = substitute_variables(quadratic_problem, constants=constants)
smaller_qubo = converter.convert(smaller_quadratic_problem)

print(f"{NUM_BONDS_TO_KEEP}-bond problem: {smaller_quadratic_problem.get_num_binary_vars()} binary variables")
print(f"QUBO variables: {smaller_qubo.get_num_vars()}")
print(f"QUBO objective sense: {smaller_qubo.objective.sense}")
print(f"QUBO constant term: {smaller_qubo.objective.constant}")
# Out:
# Total variables: 31
#
# Keeping first 10: ['iTrade_444859BR2', 'iTrade_24422EWZ8', 'iTrade_026874DS3', 'iTrade_314353AA1', 'iTrade_13645RBF0', 'iTrade_081437AT2', 'iTrade_21871XAS8', 'iTrade_540424AT5', 'iTrade_759351AP4', 'iTrade_444859BV3']
#
# Discarding remaining 21: ['iTrade_760759BC3', 'iTrade_097023CJ2', 'iTrade_444859BY7', 'iTrade_36166NAK9', 'iTrade_539830CD9', 'iTrade_75513EAD3', 'iTrade_56501RAN6', 'iTrade_444859CA8', 'iTrade_13645RAD6', 'iTrade_24422EXP9', 'iTrade_443201AC2', 'iTrade_45687VAB2', 'iTrade_438516CM6', 'iTrade_91324PEJ7', 'iTrade_655844CR7', 'iTrade_760759BA7', 'iTrade_15135BAW1', 'iTrade_14448CBC7', 'iTrade_907818FX1', 'iTrade_020002BJ9', 'iTrade_655844CT3']
#
# 10-bond problem: 10 binary variables
# QUBO variables: 10
# QUBO objective sense: ObjSense.MINIMIZE
# QUBO constant term: 0.0

# %% [markdown]
# ## Objective Function
#
# The objective function is given by the formula:
#
# $$
# \min \sum_{\ell \in L} \sum_{j \in J} \rho_j \left( \sum_{c \in K_\ell} \beta_{c,j} \, x_c - K_{\ell,j}^{\text{target}} \right)^2
# $$
#
# The goal is to minimize the difference between a portfolio's characteristics and their target values, ensuring the portfolio matches the targets as closely as possible. This objective function is handled internally by the QUBO formulation.

# %%
# create objective function
def objective_function(x):
    """Objective function for the reduced QUBO problem"""
    return smaller_qubo.objective.evaluate(x)  # uses smaller_qubo instead

# %% [markdown]
# ## IBM Quantum Setup
#
# The IBM Quantum account is loaded to select a real quantum device for execution.

# %%
# load IBM Quantum API key
try:
    with open(str(ROOT) + '/project/apikey.json', 'r') as f:
        api_key_data = json.load(f)
        api_key = api_key_data['apikey']
except Exception as e:
    raise RuntimeError(
        f"Failed to load API key from 'project/apikey.json': {str(e)}"
    )

# load IBM Quantum account
print("Loading IBM Quantum account...")
QiskitRuntimeService.save_account(token=api_key, overwrite=True)
service = QiskitRuntimeService()
print(f"Account loaded successfully!")
# Out:
# Loading IBM Quantum account...
# qiskit_runtime_service._resolve_cloud_instances:WARNING:2025-10-17 01:02:16,648: Default instance not set. Searching all available instances.
# Account loaded successfully!

# %% [markdown]
# ## Backend Configuration
#
# Using **IBM Quantum real hardware** for quantum **computation**, the backend is selected from IBM's free-tier quantum devices. Examples include:
# - ibm_torino
# - ibm_brisbane

# %%
num_vars = smaller_qubo.get_num_vars()

# get available backends
print("Fetching available backends...")
all_backends = service.backends()
print(f"Available backends/devices: {[backend.name for backend in all_backends]}")
print()

# 1. filter for real quantum devices (not simulators)
print("Filtering real quantum backends...")
real_backends = [backend for backend in all_backends if 'simulator' not in backend.name.lower()]
print(f"Real quantum backends/devices: {[real_backend.name for real_backend in real_backends]}")
print()

# 2. select the least busy real quantum device
if len(real_backends) == 0:
    raise RuntimeError("No real quantum backends/devices available!")
else:
    # use Qiskit's least_busy function to automatically select the least busy device
    backend = service.least_busy(operational=True, simulator=False)
    print(f"Backend: {backend.name} (least busy)")
    print(f"Status: {backend.status().status_msg} (Pending jobs: {backend.status().pending_jobs})")
    print(f"Number of qubits (backend): {backend.num_qubits}")
    print(f"Number of qubits (problem): {num_vars}")
# Out:
# Fetching available backends...
# Available backends/devices: ['ibm_brisbane', 'ibm_torino']
#
# Filtering real quantum backends...
# Real quantum backends/devices: ['ibm_brisbane', 'ibm_torino']
#
# Backend: ibm_torino (least busy)
# Status: active (Pending jobs: 400)
# Number of qubits (backend): 133
# Number of qubits (problem): 10

# %% [markdown]
# ## Ansatz Configuration

# %%
# TwoLocal configuration
ansatz = 'TwoLocal'
ansatz_params = {
    'reps': 2,  # low reps for shallow circuits
    'entanglement': 'full',  # full entanglement for maximum connectivity
    'rotation_blocks': 'ry',  # rotation gates
    'entanglement_blocks': 'cz',  # controlled-Z entangling gates
    'insert_barriers': False,  # no barriers for efficiency
}

print(f"Configuration: {ansatz} with {ansatz_params}")
print(f"Expected: Parameter-heavy with shallow circuits")
# Out:
# Configuration: TwoLocal with {'reps': 2, 'entanglement': 'full', 'rotation_blocks': 'ry', 'entanglement_blocks': 'cz', 'insert_barriers': False}
# Expected: Parameter-heavy with shallow circuits

# %% [markdown]
# ## Ansatz Building

# %%
# build TwoLocal ansatz
ansatz_circuit, initial_layout = build_ansatz(
    ansatz=ansatz,
    ansatz_params=ansatz_params,
    num_qubits=num_vars,
    backend=backend
)

print(f"Raw TwoLocal Ansatz has {ansatz_circuit.num_parameters} parameters")
print(f"Circuit depth: {ansatz_circuit.depth()}")
print(f"Number of gates: {len(ansatz_circuit.data)}")
print(f"Entanglement: {ansatz_params['entanglement']}")
print(f"Repetitions: {ansatz_params['reps']}")
# Out:
# Raw TwoLocal Ansatz has 30 parameters
# Circuit depth: 2
# Number of gates: 12
# Entanglement: full
# Repetitions: 2

# %% [markdown]
# ## Ansatz Transpilation

# %%
# transpile the ansatz for the target backend
print("Transpiling ansatz for target backend...")
isa_ansatz = generate_preset_pass_manager(target=backend.target, optimization_level=3, initial_layout=initial_layout).run(ansatz_circuit)

print(f"Transpiled ansatz has {isa_ansatz.num_parameters} parameters")
print(f"Transpiled circuit depth: {isa_ansatz.depth()}")
print(f"Transpiled gates: {len(isa_ansatz.data)}")
# Out:
# Transpiling ansatz for target backend...
# Transpiled ansatz has 30 parameters
# Transpiled circuit depth: 353
# Transpiled gates: 961

# %% [markdown]
# ## Conditional Value at Risk (CVaR)
#
# CVaR is a generalization of both the sample mean and the minimum. It represents the expected value of the lowest α-fraction (i.e., the lower tail) of a distribution. In this case, the distribution of sampled energy values from a quantum Hamiltonian.
#
# According to Barkoutsos et al. (2020), to compute CVaR:
#
# - The Hamiltonian is sampled (measured indirectly) *K* times.
# - Each sample yields an energy value.
# - The energy values are sorted in ascending order (lowest to highest).
# - CVaR is then calculated as the average of the lowest ⌈αK⌉ values using the formula:
#
# $$
# \text{CVaR}_\alpha = \frac{1}{\lceil \alpha K \rceil} \sum_{k=1}^{\lceil \alpha K \rceil} H_k
# $$
#
# Here, $H_k$ denotes the k-th lowest observed energy value.
#
# In implementation:
#
# - The CVaR calculation is performed by the function <code>calc_cvar()</code> in <code>"src/sbo/src/patterns/building_blocks/step3.py"</code>.
# - Sampled measurement results are mapped to energy values by the function <code>_sampler_result_to_cvar()</code> in <code>"src/sbo/src/patterns/building_blocks/step3.py"</code>.
#
# ## Standard VQE
#
# After translating a problem into QUBO form and constructing a Hamiltonian for an n-qubit system, the standard VQE algorithm samples (i.e., indirectly measures) the Hamiltonian *K* times. These measurement outcomes are summed and averaged to estimate the expectation value $\langle \psi(\theta) | H | \psi(\theta) \rangle$. The lowest expectation value, corresponding to a specific set of parameters in the chosen ansatz that minimizes the cost function, is taken as the optimal solution (bitstring) with high probability.
#
# ## CVaR-VQE
#
# In contrast, CVaR-VQE optimizes a CVaR objective, focusing on the average of the worst $\alpha$-fraction of sampled energies. The minimal CVaR value, corresponding to certain ansatz parameters minimizing this objective, is considered the optimal solution (bitstring).

# %% [markdown]
# ## Hardware Executor
#
# The HardwareExecutor orchestrates the entire VQA process. It initializes quantum circuit parameters using π/3 (≈1.047) as a reference value, which provides a good starting point for optimization. The CVaR parameters are set to focus on the worst 10% of measurements (alpha=0.1) with 512 quantum measurements per epoch.
#
# The executor uses the NFT (Natural Frequency Tuning) optimizer with the following configuration:
# - **objective_fun**: QUBO objective function to minimize
# - **backend**: Quantum hardware backend (IBM)
# - **isa_ansatz**: TwoLocal quantum circuit ansatz
# - **optimizer_theta0**: Initial parameter values
# - **optimizer_method**: NFT optimizer
# - **sampler_options**: Quantum measurement settings
# - **solver_options**: Maximum 2 epochs, CVaR parameter, random parameter updates

# %%
# initialize quantum circuit parameters
theta_initial = np.pi/3 * np.ones(isa_ansatz.num_parameters)

# cvar optimization parameters
alpha = 0.1   # cvar parameter: focus on worst 10% of measurements # -- MODIFY HERE --
shots = 512  # number of quantum measurements per epoch # -- MODIFY HERE --

# create HardwareExecutor for quantum optimization
he = HardwareExecutor(
    objective_fun=objective_function,
    backend=backend,
    isa_ansatz=isa_ansatz,  # use transpiled ansatz
    optimizer_theta0=theta_initial,
    optimizer_method="nft",
    refvalue=None,
    sampler_options={'default_shots': shots},
    use_session=False,
    verbose="progress",
    file_name=None,
    store_all_x=True,
    solver_options={
        "max_epoch": 2,  # -- MODIFY HERE --
        "alpha": alpha,
        "random_update": True
    }
)

# %% [markdown]
# ## Quantum Execution
#
# The TwoLocal VQA optimization with CVaR executes on IBM real quantum hardware, followed by local search refinement. The process involves:
#
# 1. Initialization: Quantum circuit parameters are set using π/3 as reference values
# 2. Iteration Loop: For each optimization iteration:
#    - Prepare quantum state using TwoLocal ansatz
#    - Measure Hamiltonian expectation value K times (shots)
#    - Calculate CVaR from the worst α-fraction of measurements
#    - Update parameters using NFT optimizer
# 3. Convergence: Continue until convergence or max_epoch limit
# 4. Local Search Phase: Apply classical local search to refine the best quantum solution
# 5. Final Solution: Extract the best solution from the hybrid approach
#
# **Timeout Handling:** Execution time is monitored to track performance and ensure compliance with resource constraints (QPU time limits for real hardware, or performance metrics for simulators).
#
# **Partial Results:** If execution is interrupted, the partial solution remains valid and analyzable. The `HardwareExecutor` class captures the best solution found before interruption, ensuring incomplete runs produce usable results for comparison and analysis.
#
# The optimization extracts the best solution found, which includes:
# - **best_x**: Binary vector representing selected bonds (1=selected, 0=not selected)
# - **best_fx**: Objective function value (CVaR) of the best solution

# %%
# run the TwoLocal VQA optimization with cvar
print("Starting TwoLocal VQA optimization with CVaR...")

# record start time for performance measurement
start_time = time.time()

# set maximum time limit
max_time_seconds = 9 * 60  # 9 minutes to leave 1 min buffer

# execute the variational quantum optimization
result = he.run()

# check if execution exceeded maximum time limit
if time.time() - start_time > max_time_seconds:
    print("Warning: Execution exceeded 10-minute QPU time limit!")

# record end time and calculate total optimization time
end_time = time.time()
print(f"Quantum optimization ended in {end_time - start_time:.2f} seconds")

# extract the best solution found during quantum optimization
best_x_quantum = he.optimization_monitor.objective_monitor.best_x
best_fx_quantum = he.optimization_monitor.objective_monitor.best_fx

print(f"Quantum best solution: {best_x_quantum}")
print(f"Quantum best objective value: {best_fx_quantum}")
# Out:
# 2025-10-15 11:42:55,589 INFO optimization_wrapper: run...
# 2025-10-15 11:42:55,592 DEBUG optimization_wrapper: Using X0 [1.04719755 1.04719755 1.04719755 1.04719755 1.04719755 1.04719755
#  1.04719755 1.04719755 1.04719755 1.04719755 1.04719755 1.04719755
#  1.04719755 1.04719755 1.04719755 1.04719755 1.04719755 1.04719755
#  1.04719755 1.04719755 1.04719755 1.04719755 1.04719755 1.04719755
#  1.04719755 1.04719755 1.04719755 1.04719755 1.04719755 1.04719755
#  1.04719755 1.04719755 1.04719755 1.04719755 1.04719755 1.04719755
#  1.04719755 1.04719755 1.04719755 1.04719755 1.04719755 1.04719755
#  1.04719755 1.04719755 1.04719755 1.04719755 1.04719755 1.04719755
#  1.04719755 1.04719755 1.04719755 1.04719755 1.04719755 1.04719755
#  1.04719755 1.04719755 1.04719755 1.04719755 1.04719755 1.04719755]
# 2025-10-15 11:42:55,595 INFO nft: Using parameters: max_epoch 5
# 2025-10-15 11:42:55,597 INFO nft: Using parameters: random_update True
# 2025-10-15 11:42:55,598 INFO nft: Using parameters: epoch_start 0
# 2025-10-15 11:42:55,600 INFO nft: Using parameters: idx_set_start None
# 2025-10-15 11:42:55,601 INFO nft: Using parameters: step_start 0
# Starting TwoLocal VQA optimization with CVaR...
# 2025-10-15 11:43:09,176 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([50, 41, 45, 21, 49, 11, 46, 10, 27, 57, 39, 54, 40, 30, 47, 37, 36,
#        12, 18,  4, 55, 22, 38, 26,  9, 15, 16, 59, 32, 24, 53, 19, 20,  8,
#        17, 43, 14, 44, 34, 31,  0,  3,  5, 13, 35, 51, 56,  6,  2,  7, 28,
#        52, 33, 23, 29, 42, 48, 25,  1, 58]), 'epoch': 0, 'iter_in_epoch': 0, 'update': None, 'new_core_eval': True}
# 2025-10-15 11:43:53,672 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([50, 41, 45, 21, 49, 11, 46, 10, 27, 57, 39, 54, 40, 30, 47, 37, 36,
#        12, 18,  4, 55, 22, 38, 26,  9, 15, 16, 59, 32, 24, 53, 19, 20,  8,
#        17, 43, 14, 44, 34, 31,  0,  3,  5, 13, 35, 51, 56,  6,  2,  7, 28,
#        52, 33, 23, 29, 42, 48, 25,  1, 58]), 'epoch': 0, 'iter_in_epoch': 1, 'update': np.float64(1.549483125805043), 'new_core_eval': np.True_}
# 2025-10-15 11:44:20,350 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([50, 41, 45, 21, 49, 11, 46, 10, 27, 57, 39, 54, 40, 30, 47, 37, 36,
#        12, 18,  4, 55, 22, 38, 26,  9, 15, 16, 59, 32, 24, 53, 19, 20,  8,
#        17, 43, 14, 44, 34, 31,  0,  3,  5, 13, 35, 51, 56,  6,  2,  7, 28,
#        52, 33, 23, 29, 42, 48, 25,  1, 58]), 'epoch': 0, 'iter_in_epoch': 2, 'update': np.float64(0.5580914162270252), 'new_core_eval': np.True_}
# 2025-10-15 11:45:20,094 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([50, 41, 45, 21, 49, 11, 46, 10, 27, 57, 39, 54, 40, 30, 47, 37, 36,
#        12, 18,  4, 55, 22, 38, 26,  9, 15, 16, 59, 32, 24, 53, 19, 20,  8,
#        17, 43, 14, 44, 34, 31,  0,  3,  5, 13, 35, 51, 56,  6,  2,  7, 28,
#        52, 33, 23, 29, 42, 48, 25,  1, 58]), 'epoch': 0, 'iter_in_epoch': 3, 'update': np.float64(3.0530649687447653), 'new_core_eval': np.True_}
# 2025-10-15 11:46:19,989 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([50, 41, 45, 21, 49, 11, 46, 10, 27, 57, 39, 54, 40, 30, 47, 37, 36,
#        12, 18,  4, 55, 22, 38, 26,  9, 15, 16, 59, 32, 24, 53, 19, 20,  8,
#        17, 43, 14, 44, 34, 31,  0,  3,  5, 13, 35, 51, 56,  6,  2,  7, 28,
#        52, 33, 23, 29, 42, 48, 25,  1, 58]), 'epoch': 0, 'iter_in_epoch': 4, 'update': np.float64(2.5005501175028932), 'new_core_eval': np.True_}
# 2025-10-15 11:47:28,635 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([50, 41, 45, 21, 49, 11, 46, 10, 27, 57, 39, 54, 40, 30, 47, 37, 36,
#        12, 18,  4, 55, 22, 38, 26,  9, 15, 16, 59, 32, 24, 53, 19, 20,  8,
#        17, 43, 14, 44, 34, 31,  0,  3,  5, 13, 35, 51, 56,  6,  2,  7, 28,
#        52, 33, 23, 29, 42, 48, 25,  1, 58]), 'epoch': 0, 'iter_in_epoch': 5, 'update': np.float64(2.4502774224355113), 'new_core_eval': np.True_}
# 2025-10-15 11:48:20,423 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([50, 41, 45, 21, 49, 11, 46, 10, 27, 57, 39, 54, 40, 30, 47, 37, 36,
#        12, 18,  4, 55, 22, 38, 26,  9, 15, 16, 59, 32, 24, 53, 19, 20,  8,
#        17, 43, 14, 44, 34, 31,  0,  3,  5, 13, 35, 51, 56,  6,  2,  7, 28,
#        52, 33, 23, 29, 42, 48, 25,  1, 58]), 'epoch': 0, 'iter_in_epoch': 6, 'update': np.float64(3.0938782376952725), 'new_core_eval': np.True_}
# 2025-10-15 11:49:25,115 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([50, 41, 45, 21, 49, 11, 46, 10, 27, 57, 39, 54, 40, 30, 47, 37, 36,
#        12, 18,  4, 55, 22, 38, 26,  9, 15, 16, 59, 32, 24, 53, 19, 20,  8,
#        17, 43, 14, 44, 34, 31,  0,  3,  5, 13, 35, 51, 56,  6,  2,  7, 28,
#        52, 33, 23, 29, 42, 48, 25,  1, 58]), 'epoch': 0, 'iter_in_epoch': 7, 'update': np.float64(0.6724297547296045), 'new_core_eval': np.True_}
# 2025-10-15 11:50:14,816 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([50, 41, 45, 21, 49, 11, 46, 10, 27, 57, 39, 54, 40, 30, 47, 37, 36,
#        12, 18,  4, 55, 22, 38, 26,  9, 15, 16, 59, 32, 24, 53, 19, 20,  8,
#        17, 43, 14, 44, 34, 31,  0,  3,  5, 13, 35, 51, 56,  6,  2,  7, 28,
#        52, 33, 23, 29, 42, 48, 25,  1, 58]), 'epoch': 0, 'iter_in_epoch': 8, 'update': np.float64(0.4444262276145394), 'new_core_eval': np.True_}
# 2025-10-15 11:50:50,205 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([50, 41, 45, 21, 49, 11, 46, 10, 27, 57, 39, 54, 40, 30, 47, 37, 36,
#        12, 18,  4, 55, 22, 38, 26,  9, 15, 16, 59, 32, 24, 53, 19, 20,  8,
#        17, 43, 14, 44, 34, 31,  0,  3,  5, 13, 35, 51, 56,  6,  2,  7, 28,
#        52, 33, 23, 29, 42, 48, 25,  1, 58]), 'epoch': 0, 'iter_in_epoch': 9, 'update': np.float64(3.178892201125831), 'new_core_eval': np.True_}
# 2025-10-15 11:51:19,551 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([50, 41, 45, 21, 49, 11, 46, 10, 27, 57, 39, 54, 40, 30, 47, 37, 36,
#        12, 18,  4, 55, 22, 38, 26,  9, 15, 16, 59, 32, 24, 53, 19, 20,  8,
#        17, 43, 14, 44, 34, 31,  0,  3,  5, 13, 35, 51, 56,  6,  2,  7, 28,
#        52, 33, 23, 29, 42, 48, 25,  1, 58]), 'epoch': 0, 'iter_in_epoch': 10, 'update': np.float64(0.09521760988119454), 'new_core_eval': np.True_}
# 2025-10-15 11:51:49,168 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([50, 41, 45, 21, 49, 11, 46, 10, 27, 57, 39, 54, 40, 30, 47, 37, 36,
#        12, 18,  4, 55, 22, 38, 26,  9, 15, 16, 59, 32, 24, 53, 19, 20,  8,
#        17, 43, 14, 44, 34, 31,  0,  3,  5, 13, 35, 51, 56,  6,  2,  7, 28,
#        52, 33, 23, 29, 42, 48, 25,  1, 58]), 'epoch': 0, 'iter_in_epoch': 11, 'update': np.float64(2.393706482257004), 'new_core_eval': np.True_}
# 2025-10-15 11:52:24,821 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([50, 41, 45, 21, 49, 11, 46, 10, 27, 57, 39, 54, 40, 30, 47, 37, 36,
#        12, 18,  4, 55, 22, 38, 26,  9, 15, 16, 59, 32, 24, 53, 19, 20,  8,
#        17, 43, 14, 44, 34, 31,  0,  3,  5, 13, 35, 51, 56,  6,  2,  7, 28,
#        52, 33, 23, 29, 42, 48, 25,  1, 58]), 'epoch': 0, 'iter_in_epoch': 12, 'update': np.float64(0.37041556603488424), 'new_core_eval': np.True_}
# 2025-10-15 11:52:50,716 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([50, 41, 45, 21, 49, 11, 46, 10, 27, 57, 39, 54, 40, 30, 47, 37, 36,
#        12, 18,  4, 55, 22, 38, 26,  9, 15, 16, 59, 32, 24, 53, 19, 20,  8,
#        17, 43, 14, 44, 34, 31,  0,  3,  5, 13, 35, 51, 56,  6,  2,  7, 28,
#        52, 33, 23, 29, 42, 48, 25,  1, 58]), 'epoch': 0, 'iter_in_epoch': 13, 'update': np.float64(2.5247239941022936), 'new_core_eval': np.True_}
# 2025-10-15 11:53:20,417 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([50, 41, 45, 21, 49, 11, 46, 10, 27, 57, 39, 54, 40, 30, 47, 37, 36,
#        12, 18,  4, 55, 22, 38, 26,  9, 15, 16, 59, 32, 24, 53, 19, 20,  8,
#        17, 43, 14, 44, 34, 31,  0,  3,  5, 13, 35, 51, 56,  6,  2,  7, 28,
#        52, 33, 23, 29, 42, 48, 25,  1, 58]), 'epoch': 0, 'iter_in_epoch': 14, 'update': np.float64(0.9919486842759426), 'new_core_eval': np.True_}
# 2025-10-15 11:54:03,290 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([50, 41, 45, 21, 49, 11, 46, 10, 27, 57, 39, 54, 40, 30, 47, 37, 36,
#        12, 18,  4, 55, 22, 38, 26,  9, 15, 16, 59, 32, 24, 53, 19, 20,  8,
#        17, 43, 14, 44, 34, 31,  0,  3,  5, 13, 35, 51, 56,  6,  2,  7, 28,
#        52, 33, 23, 29, 42, 48, 25,  1, 58]), 'epoch': 0, 'iter_in_epoch': 15, 'update': np.float64(3.2444343140959147), 'new_core_eval': np.True_}
# 2025-10-15 11:54:39,362 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([50, 41, 45, 21, 49, 11, 46, 10, 27, 57, 39, 54, 40, 30, 47, 37, 36,
#        12, 18,  4, 55, 22, 38, 26,  9, 15, 16, 59, 32, 24, 53, 19, 20,  8,
#        17, 43, 14, 44, 34, 31,  0,  3,  5, 13, 35, 51, 56,  6,  2,  7, 28,
#        52, 33, 23, 29, 42, 48, 25,  1, 58]), 'epoch': 0, 'iter_in_epoch': 16, 'update': np.float64(0.17521224796109292), 'new_core_eval': np.True_}
# 2025-10-15 11:55:24,972 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([50, 41, 45, 21, 49, 11, 46, 10, 27, 57, 39, 54, 40, 30, 47, 37, 36,
#        12, 18,  4, 55, 22, 38, 26,  9, 15, 16, 59, 32, 24, 53, 19, 20,  8,
#        17, 43, 14, 44, 34, 31,  0,  3,  5, 13, 35, 51, 56,  6,  2,  7, 28,
#        52, 33, 23, 29, 42, 48, 25,  1, 58]), 'epoch': 0, 'iter_in_epoch': 17, 'update': np.float64(2.9777670677887063), 'new_core_eval': np.True_}
# 2025-10-15 11:56:07,436 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([50, 41, 45, 21, 49, 11, 46, 10, 27, 57, 39, 54, 40, 30, 47, 37, 36,
#        12, 18,  4, 55, 22, 38, 26,  9, 15, 16, 59, 32, 24, 53, 19, 20,  8,
#        17, 43, 14, 44, 34, 31,  0,  3,  5, 13, 35, 51, 56,  6,  2,  7, 28,
#        52, 33, 23, 29, 42, 48, 25,  1, 58]), 'epoch': 0, 'iter_in_epoch': 18, 'update': np.float64(0.08802509698871153), 'new_core_eval': np.True_}
# 2025-10-15 11:56:34,007 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([50, 41, 45, 21, 49, 11, 46, 10, 27, 57, 39, 54, 40, 30, 47, 37, 36,
#        12, 18,  4, 55, 22, 38, 26,  9, 15, 16, 59, 32, 24, 53, 19, 20,  8,
#        17, 43, 14, 44, 34, 31,  0,  3,  5, 13, 35, 51, 56,  6,  2,  7, 28,
#        52, 33, 23, 29, 42, 48, 25,  1, 58]), 'epoch': 0, 'iter_in_epoch': 19, 'update': np.float64(2.6897648720539546), 'new_core_eval': np.True_}
# 2025-10-15 11:58:05,076 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([50, 41, 45, 21, 49, 11, 46, 10, 27, 57, 39, 54, 40, 30, 47, 37, 36,
#        12, 18,  4, 55, 22, 38, 26,  9, 15, 16, 59, 32, 24, 53, 19, 20,  8,
#        17, 43, 14, 44, 34, 31,  0,  3,  5, 13, 35, 51, 56,  6,  2,  7, 28,
#        52, 33, 23, 29, 42, 48, 25,  1, 58]), 'epoch': 0, 'iter_in_epoch': 20, 'update': np.float64(2.300091258913704), 'new_core_eval': np.True_}
# 2025-10-15 11:59:30,277 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([50, 41, 45, 21, 49, 11, 46, 10, 27, 57, 39, 54, 40, 30, 47, 37, 36,
#        12, 18,  4, 55, 22, 38, 26,  9, 15, 16, 59, 32, 24, 53, 19, 20,  8,
#        17, 43, 14, 44, 34, 31,  0,  3,  5, 13, 35, 51, 56,  6,  2,  7, 28,
#        52, 33, 23, 29, 42, 48, 25,  1, 58]), 'epoch': 0, 'iter_in_epoch': 21, 'update': np.float64(3.6625447397223425), 'new_core_eval': np.True_}
# 2025-10-15 12:00:59,300 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([50, 41, 45, 21, 49, 11, 46, 10, 27, 57, 39, 54, 40, 30, 47, 37, 36,
#        12, 18,  4, 55, 22, 38, 26,  9, 15, 16, 59, 32, 24, 53, 19, 20,  8,
#        17, 43, 14, 44, 34, 31,  0,  3,  5, 13, 35, 51, 56,  6,  2,  7, 28,
#        52, 33, 23, 29, 42, 48, 25,  1, 58]), 'epoch': 0, 'iter_in_epoch': 22, 'update': np.float64(2.9481777927968666), 'new_core_eval': np.True_}
# 2025-10-15 12:02:30,490 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([50, 41, 45, 21, 49, 11, 46, 10, 27, 57, 39, 54, 40, 30, 47, 37, 36,
#        12, 18,  4, 55, 22, 38, 26,  9, 15, 16, 59, 32, 24, 53, 19, 20,  8,
#        17, 43, 14, 44, 34, 31,  0,  3,  5, 13, 35, 51, 56,  6,  2,  7, 28,
#        52, 33, 23, 29, 42, 48, 25,  1, 58]), 'epoch': 0, 'iter_in_epoch': 23, 'update': np.float64(-1.1403386479319846), 'new_core_eval': np.True_}
# 2025-10-15 12:03:59,839 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([50, 41, 45, 21, 49, 11, 46, 10, 27, 57, 39, 54, 40, 30, 47, 37, 36,
#        12, 18,  4, 55, 22, 38, 26,  9, 15, 16, 59, 32, 24, 53, 19, 20,  8,
#        17, 43, 14, 44, 34, 31,  0,  3,  5, 13, 35, 51, 56,  6,  2,  7, 28,
#        52, 33, 23, 29, 42, 48, 25,  1, 58]), 'epoch': 0, 'iter_in_epoch': 24, 'update': np.float64(3.8116803801853507), 'new_core_eval': np.True_}
# 2025-10-15 12:05:28,264 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([50, 41, 45, 21, 49, 11, 46, 10, 27, 57, 39, 54, 40, 30, 47, 37, 36,
#        12, 18,  4, 55, 22, 38, 26,  9, 15, 16, 59, 32, 24, 53, 19, 20,  8,
#        17, 43, 14, 44, 34, 31,  0,  3,  5, 13, 35, 51, 56,  6,  2,  7, 28,
#        52, 33, 23, 29, 42, 48, 25,  1, 58]), 'epoch': 0, 'iter_in_epoch': 25, 'update': np.float64(-0.5709904165268127), 'new_core_eval': np.True_}
# 2025-10-15 12:07:32,334 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([50, 41, 45, 21, 49, 11, 46, 10, 27, 57, 39, 54, 40, 30, 47, 37, 36,
#        12, 18,  4, 55, 22, 38, 26,  9, 15, 16, 59, 32, 24, 53, 19, 20,  8,
#        17, 43, 14, 44, 34, 31,  0,  3,  5, 13, 35, 51, 56,  6,  2,  7, 28,
#        52, 33, 23, 29, 42, 48, 25,  1, 58]), 'epoch': 0, 'iter_in_epoch': 26, 'update': np.float64(0.9138863770022587), 'new_core_eval': np.True_}
# 2025-10-15 12:12:05,531 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([50, 41, 45, 21, 49, 11, 46, 10, 27, 57, 39, 54, 40, 30, 47, 37, 36,
#        12, 18,  4, 55, 22, 38, 26,  9, 15, 16, 59, 32, 24, 53, 19, 20,  8,
#        17, 43, 14, 44, 34, 31,  0,  3,  5, 13, 35, 51, 56,  6,  2,  7, 28,
#        52, 33, 23, 29, 42, 48, 25,  1, 58]), 'epoch': 0, 'iter_in_epoch': 28, 'update': np.float64(3.767180625240467), 'new_core_eval': np.True_}
# 2025-10-15 12:12:28,441 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([50, 41, 45, 21, 49, 11, 46, 10, 27, 57, 39, 54, 40, 30, 47, 37, 36,
#        12, 18,  4, 55, 22, 38, 26,  9, 15, 16, 59, 32, 24, 53, 19, 20,  8,
#        17, 43, 14, 44, 34, 31,  0,  3,  5, 13, 35, 51, 56,  6,  2,  7, 28,
#        52, 33, 23, 29, 42, 48, 25,  1, 58]), 'epoch': 0, 'iter_in_epoch': 29, 'update': np.float64(0.27028191807840307), 'new_core_eval': np.True_}
# 2025-10-15 12:12:51,674 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([50, 41, 45, 21, 49, 11, 46, 10, 27, 57, 39, 54, 40, 30, 47, 37, 36,
#        12, 18,  4, 55, 22, 38, 26,  9, 15, 16, 59, 32, 24, 53, 19, 20,  8,
#        17, 43, 14, 44, 34, 31,  0,  3,  5, 13, 35, 51, 56,  6,  2,  7, 28,
#        52, 33, 23, 29, 42, 48, 25,  1, 58]), 'epoch': 0, 'iter_in_epoch': 30, 'update': np.float64(-0.2639293791821442), 'new_core_eval': np.True_}
# 2025-10-15 12:13:15,982 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([50, 41, 45, 21, 49, 11, 46, 10, 27, 57, 39, 54, 40, 30, 47, 37, 36,
#        12, 18,  4, 55, 22, 38, 26,  9, 15, 16, 59, 32, 24, 53, 19, 20,  8,
#        17, 43, 14, 44, 34, 31,  0,  3,  5, 13, 35, 51, 56,  6,  2,  7, 28,
#        52, 33, 23, 29, 42, 48, 25,  1, 58]), 'epoch': 0, 'iter_in_epoch': 31, 'update': np.float64(2.8019051390034013), 'new_core_eval': np.True_}
# 2025-10-15 12:13:39,004 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([50, 41, 45, 21, 49, 11, 46, 10, 27, 57, 39, 54, 40, 30, 47, 37, 36,
#        12, 18,  4, 55, 22, 38, 26,  9, 15, 16, 59, 32, 24, 53, 19, 20,  8,
#        17, 43, 14, 44, 34, 31,  0,  3,  5, 13, 35, 51, 56,  6,  2,  7, 28,
#        52, 33, 23, 29, 42, 48, 25,  1, 58]), 'epoch': 0, 'iter_in_epoch': 32, 'update': np.float64(-0.6343654695813147), 'new_core_eval': np.True_}
# 2025-10-15 12:14:03,147 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([50, 41, 45, 21, 49, 11, 46, 10, 27, 57, 39, 54, 40, 30, 47, 37, 36,
#        12, 18,  4, 55, 22, 38, 26,  9, 15, 16, 59, 32, 24, 53, 19, 20,  8,
#        17, 43, 14, 44, 34, 31,  0,  3,  5, 13, 35, 51, 56,  6,  2,  7, 28,
#        52, 33, 23, 29, 42, 48, 25,  1, 58]), 'epoch': 0, 'iter_in_epoch': 33, 'update': np.float64(-0.5891068654792255), 'new_core_eval': np.True_}
# 2025-10-15 12:14:25,403 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([50, 41, 45, 21, 49, 11, 46, 10, 27, 57, 39, 54, 40, 30, 47, 37, 36,
#        12, 18,  4, 55, 22, 38, 26,  9, 15, 16, 59, 32, 24, 53, 19, 20,  8,
#        17, 43, 14, 44, 34, 31,  0,  3,  5, 13, 35, 51, 56,  6,  2,  7, 28,
#        52, 33, 23, 29, 42, 48, 25,  1, 58]), 'epoch': 0, 'iter_in_epoch': 34, 'update': np.float64(0.8769141274106806), 'new_core_eval': np.True_}
# 2025-10-15 12:14:48,915 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([50, 41, 45, 21, 49, 11, 46, 10, 27, 57, 39, 54, 40, 30, 47, 37, 36,
#        12, 18,  4, 55, 22, 38, 26,  9, 15, 16, 59, 32, 24, 53, 19, 20,  8,
#        17, 43, 14, 44, 34, 31,  0,  3,  5, 13, 35, 51, 56,  6,  2,  7, 28,
#        52, 33, 23, 29, 42, 48, 25,  1, 58]), 'epoch': 0, 'iter_in_epoch': 35, 'update': np.float64(2.6487319380460566), 'new_core_eval': np.True_}
# 2025-10-15 12:15:12,963 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([50, 41, 45, 21, 49, 11, 46, 10, 27, 57, 39, 54, 40, 30, 47, 37, 36,
#        12, 18,  4, 55, 22, 38, 26,  9, 15, 16, 59, 32, 24, 53, 19, 20,  8,
#        17, 43, 14, 44, 34, 31,  0,  3,  5, 13, 35, 51, 56,  6,  2,  7, 28,
#        52, 33, 23, 29, 42, 48, 25,  1, 58]), 'epoch': 0, 'iter_in_epoch': 36, 'update': np.float64(2.8888987727740254), 'new_core_eval': np.True_}
# 2025-10-15 12:15:37,115 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([50, 41, 45, 21, 49, 11, 46, 10, 27, 57, 39, 54, 40, 30, 47, 37, 36,
#        12, 18,  4, 55, 22, 38, 26,  9, 15, 16, 59, 32, 24, 53, 19, 20,  8,
#        17, 43, 14, 44, 34, 31,  0,  3,  5, 13, 35, 51, 56,  6,  2,  7, 28,
#        52, 33, 23, 29, 42, 48, 25,  1, 58]), 'epoch': 0, 'iter_in_epoch': 37, 'update': np.float64(4.50584930608953), 'new_core_eval': np.True_}
# 2025-10-15 12:16:01,004 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([50, 41, 45, 21, 49, 11, 46, 10, 27, 57, 39, 54, 40, 30, 47, 37, 36,
#        12, 18,  4, 55, 22, 38, 26,  9, 15, 16, 59, 32, 24, 53, 19, 20,  8,
#        17, 43, 14, 44, 34, 31,  0,  3,  5, 13, 35, 51, 56,  6,  2,  7, 28,
#        52, 33, 23, 29, 42, 48, 25,  1, 58]), 'epoch': 0, 'iter_in_epoch': 38, 'update': np.float64(4.0247272936550615), 'new_core_eval': np.True_}
# 2025-10-15 12:16:24,941 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([50, 41, 45, 21, 49, 11, 46, 10, 27, 57, 39, 54, 40, 30, 47, 37, 36,
#        12, 18,  4, 55, 22, 38, 26,  9, 15, 16, 59, 32, 24, 53, 19, 20,  8,
#        17, 43, 14, 44, 34, 31,  0,  3,  5, 13, 35, 51, 56,  6,  2,  7, 28,
#        52, 33, 23, 29, 42, 48, 25,  1, 58]), 'epoch': 0, 'iter_in_epoch': 39, 'update': np.float64(-0.0008688376031342759), 'new_core_eval': np.True_}
# 2025-10-15 12:16:48,620 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([50, 41, 45, 21, 49, 11, 46, 10, 27, 57, 39, 54, 40, 30, 47, 37, 36,
#        12, 18,  4, 55, 22, 38, 26,  9, 15, 16, 59, 32, 24, 53, 19, 20,  8,
#        17, 43, 14, 44, 34, 31,  0,  3,  5, 13, 35, 51, 56,  6,  2,  7, 28,
#        52, 33, 23, 29, 42, 48, 25,  1, 58]), 'epoch': 0, 'iter_in_epoch': 40, 'update': np.float64(4.591473230784864), 'new_core_eval': np.True_}
# 2025-10-15 12:17:12,437 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([50, 41, 45, 21, 49, 11, 46, 10, 27, 57, 39, 54, 40, 30, 47, 37, 36,
#        12, 18,  4, 55, 22, 38, 26,  9, 15, 16, 59, 32, 24, 53, 19, 20,  8,
#        17, 43, 14, 44, 34, 31,  0,  3,  5, 13, 35, 51, 56,  6,  2,  7, 28,
#        52, 33, 23, 29, 42, 48, 25,  1, 58]), 'epoch': 0, 'iter_in_epoch': 41, 'update': np.float64(0.5818843512239391), 'new_core_eval': np.True_}
# 2025-10-15 12:17:36,253 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([50, 41, 45, 21, 49, 11, 46, 10, 27, 57, 39, 54, 40, 30, 47, 37, 36,
#        12, 18,  4, 55, 22, 38, 26,  9, 15, 16, 59, 32, 24, 53, 19, 20,  8,
#        17, 43, 14, 44, 34, 31,  0,  3,  5, 13, 35, 51, 56,  6,  2,  7, 28,
#        52, 33, 23, 29, 42, 48, 25,  1, 58]), 'epoch': 0, 'iter_in_epoch': 42, 'update': np.float64(1.921456709796842), 'new_core_eval': np.True_}
# 2025-10-15 12:18:00,422 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([50, 41, 45, 21, 49, 11, 46, 10, 27, 57, 39, 54, 40, 30, 47, 37, 36,
#        12, 18,  4, 55, 22, 38, 26,  9, 15, 16, 59, 32, 24, 53, 19, 20,  8,
#        17, 43, 14, 44, 34, 31,  0,  3,  5, 13, 35, 51, 56,  6,  2,  7, 28,
#        52, 33, 23, 29, 42, 48, 25,  1, 58]), 'epoch': 0, 'iter_in_epoch': 43, 'update': np.float64(4.662371391072555), 'new_core_eval': np.True_}
# 2025-10-15 12:18:24,072 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([50, 41, 45, 21, 49, 11, 46, 10, 27, 57, 39, 54, 40, 30, 47, 37, 36,
#        12, 18,  4, 55, 22, 38, 26,  9, 15, 16, 59, 32, 24, 53, 19, 20,  8,
#        17, 43, 14, 44, 34, 31,  0,  3,  5, 13, 35, 51, 56,  6,  2,  7, 28,
#        52, 33, 23, 29, 42, 48, 25,  1, 58]), 'epoch': 0, 'iter_in_epoch': 44, 'update': np.float64(-0.3442338184525311), 'new_core_eval': np.True_}
# 2025-10-15 12:18:46,712 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([50, 41, 45, 21, 49, 11, 46, 10, 27, 57, 39, 54, 40, 30, 47, 37, 36,
#        12, 18,  4, 55, 22, 38, 26,  9, 15, 16, 59, 32, 24, 53, 19, 20,  8,
#        17, 43, 14, 44, 34, 31,  0,  3,  5, 13, 35, 51, 56,  6,  2,  7, 28,
#        52, 33, 23, 29, 42, 48, 25,  1, 58]), 'epoch': 0, 'iter_in_epoch': 45, 'update': np.float64(3.391232774768164), 'new_core_eval': np.True_}
# 2025-10-15 12:19:10,558 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([50, 41, 45, 21, 49, 11, 46, 10, 27, 57, 39, 54, 40, 30, 47, 37, 36,
#        12, 18,  4, 55, 22, 38, 26,  9, 15, 16, 59, 32, 24, 53, 19, 20,  8,
#        17, 43, 14, 44, 34, 31,  0,  3,  5, 13, 35, 51, 56,  6,  2,  7, 28,
#        52, 33, 23, 29, 42, 48, 25,  1, 58]), 'epoch': 0, 'iter_in_epoch': 46, 'update': np.float64(-0.04350157473694383), 'new_core_eval': np.True_}
# 2025-10-15 12:20:25,490 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([50, 41, 45, 21, 49, 11, 46, 10, 27, 57, 39, 54, 40, 30, 47, 37, 36,
#        12, 18,  4, 55, 22, 38, 26,  9, 15, 16, 59, 32, 24, 53, 19, 20,  8,
#        17, 43, 14, 44, 34, 31,  0,  3,  5, 13, 35, 51, 56,  6,  2,  7, 28,
#        52, 33, 23, 29, 42, 48, 25,  1, 58]), 'epoch': 0, 'iter_in_epoch': 47, 'update': np.float64(-0.5157969608755707), 'new_core_eval': np.True_}
# 2025-10-15 12:21:10,984 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([50, 41, 45, 21, 49, 11, 46, 10, 27, 57, 39, 54, 40, 30, 47, 37, 36,
#        12, 18,  4, 55, 22, 38, 26,  9, 15, 16, 59, 32, 24, 53, 19, 20,  8,
#        17, 43, 14, 44, 34, 31,  0,  3,  5, 13, 35, 51, 56,  6,  2,  7, 28,
#        52, 33, 23, 29, 42, 48, 25,  1, 58]), 'epoch': 0, 'iter_in_epoch': 48, 'update': np.float64(3.075849292272525), 'new_core_eval': np.True_}
# 2025-10-15 12:21:35,375 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([50, 41, 45, 21, 49, 11, 46, 10, 27, 57, 39, 54, 40, 30, 47, 37, 36,
#        12, 18,  4, 55, 22, 38, 26,  9, 15, 16, 59, 32, 24, 53, 19, 20,  8,
#        17, 43, 14, 44, 34, 31,  0,  3,  5, 13, 35, 51, 56,  6,  2,  7, 28,
#        52, 33, 23, 29, 42, 48, 25,  1, 58]), 'epoch': 0, 'iter_in_epoch': 49, 'update': np.float64(3.1178080074881667), 'new_core_eval': np.True_}
# 2025-10-15 12:22:29,726 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([50, 41, 45, 21, 49, 11, 46, 10, 27, 57, 39, 54, 40, 30, 47, 37, 36,
#        12, 18,  4, 55, 22, 38, 26,  9, 15, 16, 59, 32, 24, 53, 19, 20,  8,
#        17, 43, 14, 44, 34, 31,  0,  3,  5, 13, 35, 51, 56,  6,  2,  7, 28,
#        52, 33, 23, 29, 42, 48, 25,  1, 58]), 'epoch': 0, 'iter_in_epoch': 50, 'update': np.float64(3.0037601820860047), 'new_core_eval': np.True_}
# 2025-10-15 12:23:19,262 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([50, 41, 45, 21, 49, 11, 46, 10, 27, 57, 39, 54, 40, 30, 47, 37, 36,
#        12, 18,  4, 55, 22, 38, 26,  9, 15, 16, 59, 32, 24, 53, 19, 20,  8,
#        17, 43, 14, 44, 34, 31,  0,  3,  5, 13, 35, 51, 56,  6,  2,  7, 28,
#        52, 33, 23, 29, 42, 48, 25,  1, 58]), 'epoch': 0, 'iter_in_epoch': 51, 'update': np.float64(0.24585364542709098), 'new_core_eval': np.True_}
# 2025-10-15 12:24:37,345 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([50, 41, 45, 21, 49, 11, 46, 10, 27, 57, 39, 54, 40, 30, 47, 37, 36,
#        12, 18,  4, 55, 22, 38, 26,  9, 15, 16, 59, 32, 24, 53, 19, 20,  8,
#        17, 43, 14, 44, 34, 31,  0,  3,  5, 13, 35, 51, 56,  6,  2,  7, 28,
#        52, 33, 23, 29, 42, 48, 25,  1, 58]), 'epoch': 0, 'iter_in_epoch': 52, 'update': np.float64(2.0891640876487765), 'new_core_eval': np.True_}
# 2025-10-15 12:25:01,799 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([50, 41, 45, 21, 49, 11, 46, 10, 27, 57, 39, 54, 40, 30, 47, 37, 36,
#        12, 18,  4, 55, 22, 38, 26,  9, 15, 16, 59, 32, 24, 53, 19, 20,  8,
#        17, 43, 14, 44, 34, 31,  0,  3,  5, 13, 35, 51, 56,  6,  2,  7, 28,
#        52, 33, 23, 29, 42, 48, 25,  1, 58]), 'epoch': 0, 'iter_in_epoch': 53, 'update': np.float64(3.72515995312994), 'new_core_eval': np.True_}
# 2025-10-15 12:26:00,070 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([50, 41, 45, 21, 49, 11, 46, 10, 27, 57, 39, 54, 40, 30, 47, 37, 36,
#        12, 18,  4, 55, 22, 38, 26,  9, 15, 16, 59, 32, 24, 53, 19, 20,  8,
#        17, 43, 14, 44, 34, 31,  0,  3,  5, 13, 35, 51, 56,  6,  2,  7, 28,
#        52, 33, 23, 29, 42, 48, 25,  1, 58]), 'epoch': 0, 'iter_in_epoch': 54, 'update': np.float64(-0.26830917150330647), 'new_core_eval': np.True_}
# 2025-10-15 12:26:54,132 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([50, 41, 45, 21, 49, 11, 46, 10, 27, 57, 39, 54, 40, 30, 47, 37, 36,
#        12, 18,  4, 55, 22, 38, 26,  9, 15, 16, 59, 32, 24, 53, 19, 20,  8,
#        17, 43, 14, 44, 34, 31,  0,  3,  5, 13, 35, 51, 56,  6,  2,  7, 28,
#        52, 33, 23, 29, 42, 48, 25,  1, 58]), 'epoch': 0, 'iter_in_epoch': 55, 'update': np.float64(-1.116159535637758), 'new_core_eval': np.True_}
# 2025-10-15 12:28:12,241 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([50, 41, 45, 21, 49, 11, 46, 10, 27, 57, 39, 54, 40, 30, 47, 37, 36,
#        12, 18,  4, 55, 22, 38, 26,  9, 15, 16, 59, 32, 24, 53, 19, 20,  8,
#        17, 43, 14, 44, 34, 31,  0,  3,  5, 13, 35, 51, 56,  6,  2,  7, 28,
#        52, 33, 23, 29, 42, 48, 25,  1, 58]), 'epoch': 0, 'iter_in_epoch': 56, 'update': np.float64(1.2465959337383754), 'new_core_eval': np.True_}
# 2025-10-15 12:29:03,069 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([50, 41, 45, 21, 49, 11, 46, 10, 27, 57, 39, 54, 40, 30, 47, 37, 36,
#        12, 18,  4, 55, 22, 38, 26,  9, 15, 16, 59, 32, 24, 53, 19, 20,  8,
#        17, 43, 14, 44, 34, 31,  0,  3,  5, 13, 35, 51, 56,  6,  2,  7, 28,
#        52, 33, 23, 29, 42, 48, 25,  1, 58]), 'epoch': 0, 'iter_in_epoch': 57, 'update': np.float64(1.2011454493787717), 'new_core_eval': np.True_}
# 2025-10-15 12:29:56,027 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([50, 41, 45, 21, 49, 11, 46, 10, 27, 57, 39, 54, 40, 30, 47, 37, 36,
#        12, 18,  4, 55, 22, 38, 26,  9, 15, 16, 59, 32, 24, 53, 19, 20,  8,
#        17, 43, 14, 44, 34, 31,  0,  3,  5, 13, 35, 51, 56,  6,  2,  7, 28,
#        52, 33, 23, 29, 42, 48, 25,  1, 58]), 'epoch': 0, 'iter_in_epoch': 58, 'update': np.float64(4.120915942623398), 'new_core_eval': np.True_}
# 2025-10-15 12:30:54,301 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([50, 41, 45, 21, 49, 11, 46, 10, 27, 57, 39, 54, 40, 30, 47, 37, 36,
#        12, 18,  4, 55, 22, 38, 26,  9, 15, 16, 59, 32, 24, 53, 19, 20,  8,
#        17, 43, 14, 44, 34, 31,  0,  3,  5, 13, 35, 51, 56,  6,  2,  7, 28,
#        52, 33, 23, 29, 42, 48, 25,  1, 58]), 'epoch': 0, 'iter_in_epoch': 59, 'update': np.float64(0.3017759998110938), 'new_core_eval': np.True_}
# 2025-10-15 12:31:21,038 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([46,  8, 37,  1, 19, 58, 44, 48, 50, 43, 23, 47,  3, 22, 27, 57, 59,
#        12, 54, 41, 42, 15, 17, 16,  0, 14, 34, 11, 31, 20, 18,  9, 35,  2,
#        28,  6, 51, 26,  4, 56, 25, 55, 33, 36, 24, 52, 29, 32, 40, 38, 30,
#        39, 49,  7, 13, 53,  5, 10, 45, 21]), 'epoch': 1, 'iter_in_epoch': 0, 'update': np.float64(0.15765188751627268), 'new_core_eval': np.True_}
# 2025-10-15 12:31:47,610 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([46,  8, 37,  1, 19, 58, 44, 48, 50, 43, 23, 47,  3, 22, 27, 57, 59,
#        12, 54, 41, 42, 15, 17, 16,  0, 14, 34, 11, 31, 20, 18,  9, 35,  2,
#        28,  6, 51, 26,  4, 56, 25, 55, 33, 36, 24, 52, 29, 32, 40, 38, 30,
#        39, 49,  7, 13, 53,  5, 10, 45, 21]), 'epoch': 1, 'iter_in_epoch': 1, 'update': np.float64(-0.8448239019544302), 'new_core_eval': np.True_}
# 2025-10-15 12:33:06,875 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([46,  8, 37,  1, 19, 58, 44, 48, 50, 43, 23, 47,  3, 22, 27, 57, 59,
#        12, 54, 41, 42, 15, 17, 16,  0, 14, 34, 11, 31, 20, 18,  9, 35,  2,
#        28,  6, 51, 26,  4, 56, 25, 55, 33, 36, 24, 52, 29, 32, 40, 38, 30,
#        39, 49,  7, 13, 53,  5, 10, 45, 21]), 'epoch': 1, 'iter_in_epoch': 2, 'update': np.float64(1.0741288743619988), 'new_core_eval': np.True_}
# 2025-10-15 12:33:32,032 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([46,  8, 37,  1, 19, 58, 44, 48, 50, 43, 23, 47,  3, 22, 27, 57, 59,
#        12, 54, 41, 42, 15, 17, 16,  0, 14, 34, 11, 31, 20, 18,  9, 35,  2,
#        28,  6, 51, 26,  4, 56, 25, 55, 33, 36, 24, 52, 29, 32, 40, 38, 30,
#        39, 49,  7, 13, 53,  5, 10, 45, 21]), 'epoch': 1, 'iter_in_epoch': 3, 'update': np.float64(3.2928087566248823), 'new_core_eval': np.True_}
# 2025-10-15 12:34:23,149 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([46,  8, 37,  1, 19, 58, 44, 48, 50, 43, 23, 47,  3, 22, 27, 57, 59,
#        12, 54, 41, 42, 15, 17, 16,  0, 14, 34, 11, 31, 20, 18,  9, 35,  2,
#        28,  6, 51, 26,  4, 56, 25, 55, 33, 36, 24, 52, 29, 32, 40, 38, 30,
#        39, 49,  7, 13, 53,  5, 10, 45, 21]), 'epoch': 1, 'iter_in_epoch': 4, 'update': np.float64(1.245858852615417), 'new_core_eval': np.True_}
# 2025-10-15 12:35:12,153 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([46,  8, 37,  1, 19, 58, 44, 48, 50, 43, 23, 47,  3, 22, 27, 57, 59,
#        12, 54, 41, 42, 15, 17, 16,  0, 14, 34, 11, 31, 20, 18,  9, 35,  2,
#        28,  6, 51, 26,  4, 56, 25, 55, 33, 36, 24, 52, 29, 32, 40, 38, 30,
#        39, 49,  7, 13, 53,  5, 10, 45, 21]), 'epoch': 1, 'iter_in_epoch': 5, 'update': np.float64(-1.0164015532679627), 'new_core_eval': np.True_}
# 2025-10-15 12:36:07,493 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([46,  8, 37,  1, 19, 58, 44, 48, 50, 43, 23, 47,  3, 22, 27, 57, 59,
#        12, 54, 41, 42, 15, 17, 16,  0, 14, 34, 11, 31, 20, 18,  9, 35,  2,
#        28,  6, 51, 26,  4, 56, 25, 55, 33, 36, 24, 52, 29, 32, 40, 38, 30,
#        39, 49,  7, 13, 53,  5, 10, 45, 21]), 'epoch': 1, 'iter_in_epoch': 6, 'update': np.float64(4.086237628349917), 'new_core_eval': np.True_}
# 2025-10-15 12:36:55,978 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([46,  8, 37,  1, 19, 58, 44, 48, 50, 43, 23, 47,  3, 22, 27, 57, 59,
#        12, 54, 41, 42, 15, 17, 16,  0, 14, 34, 11, 31, 20, 18,  9, 35,  2,
#        28,  6, 51, 26,  4, 56, 25, 55, 33, 36, 24, 52, 29, 32, 40, 38, 30,
#        39, 49,  7, 13, 53,  5, 10, 45, 21]), 'epoch': 1, 'iter_in_epoch': 7, 'update': np.float64(0.637968383112919), 'new_core_eval': np.True_}
# 2025-10-15 12:37:21,476 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([46,  8, 37,  1, 19, 58, 44, 48, 50, 43, 23, 47,  3, 22, 27, 57, 59,
#        12, 54, 41, 42, 15, 17, 16,  0, 14, 34, 11, 31, 20, 18,  9, 35,  2,
#        28,  6, 51, 26,  4, 56, 25, 55, 33, 36, 24, 52, 29, 32, 40, 38, 30,
#        39, 49,  7, 13, 53,  5, 10, 45, 21]), 'epoch': 1, 'iter_in_epoch': 8, 'update': np.float64(3.0901589743179523), 'new_core_eval': np.True_}
# 2025-10-15 12:38:05,636 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([46,  8, 37,  1, 19, 58, 44, 48, 50, 43, 23, 47,  3, 22, 27, 57, 59,
#        12, 54, 41, 42, 15, 17, 16,  0, 14, 34, 11, 31, 20, 18,  9, 35,  2,
#        28,  6, 51, 26,  4, 56, 25, 55, 33, 36, 24, 52, 29, 32, 40, 38, 30,
#        39, 49,  7, 13, 53,  5, 10, 45, 21]), 'epoch': 1, 'iter_in_epoch': 9, 'update': np.float64(-0.440049348407042), 'new_core_eval': np.True_}
# 2025-10-15 12:38:51,061 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([46,  8, 37,  1, 19, 58, 44, 48, 50, 43, 23, 47,  3, 22, 27, 57, 59,
#        12, 54, 41, 42, 15, 17, 16,  0, 14, 34, 11, 31, 20, 18,  9, 35,  2,
#        28,  6, 51, 26,  4, 56, 25, 55, 33, 36, 24, 52, 29, 32, 40, 38, 30,
#        39, 49,  7, 13, 53,  5, 10, 45, 21]), 'epoch': 1, 'iter_in_epoch': 10, 'update': np.float64(0.18928417038523015), 'new_core_eval': np.True_}
# 2025-10-15 12:39:38,243 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([46,  8, 37,  1, 19, 58, 44, 48, 50, 43, 23, 47,  3, 22, 27, 57, 59,
#        12, 54, 41, 42, 15, 17, 16,  0, 14, 34, 11, 31, 20, 18,  9, 35,  2,
#        28,  6, 51, 26,  4, 56, 25, 55, 33, 36, 24, 52, 29, 32, 40, 38, 30,
#        39, 49,  7, 13, 53,  5, 10, 45, 21]), 'epoch': 1, 'iter_in_epoch': 11, 'update': np.float64(0.6440109835260622), 'new_core_eval': np.True_}
# 2025-10-15 12:40:02,510 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([46,  8, 37,  1, 19, 58, 44, 48, 50, 43, 23, 47,  3, 22, 27, 57, 59,
#        12, 54, 41, 42, 15, 17, 16,  0, 14, 34, 11, 31, 20, 18,  9, 35,  2,
#        28,  6, 51, 26,  4, 56, 25, 55, 33, 36, 24, 52, 29, 32, 40, 38, 30,
#        39, 49,  7, 13, 53,  5, 10, 45, 21]), 'epoch': 1, 'iter_in_epoch': 12, 'update': np.float64(-1.3289335067073411), 'new_core_eval': np.True_}
# 2025-10-15 12:40:50,366 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([46,  8, 37,  1, 19, 58, 44, 48, 50, 43, 23, 47,  3, 22, 27, 57, 59,
#        12, 54, 41, 42, 15, 17, 16,  0, 14, 34, 11, 31, 20, 18,  9, 35,  2,
#        28,  6, 51, 26,  4, 56, 25, 55, 33, 36, 24, 52, 29, 32, 40, 38, 30,
#        39, 49,  7, 13, 53,  5, 10, 45, 21]), 'epoch': 1, 'iter_in_epoch': 13, 'update': np.float64(-0.7263349621658177), 'new_core_eval': np.True_}
# 2025-10-15 12:41:15,982 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([46,  8, 37,  1, 19, 58, 44, 48, 50, 43, 23, 47,  3, 22, 27, 57, 59,
#        12, 54, 41, 42, 15, 17, 16,  0, 14, 34, 11, 31, 20, 18,  9, 35,  2,
#        28,  6, 51, 26,  4, 56, 25, 55, 33, 36, 24, 52, 29, 32, 40, 38, 30,
#        39, 49,  7, 13, 53,  5, 10, 45, 21]), 'epoch': 1, 'iter_in_epoch': 14, 'update': np.float64(-1.5654350283327583), 'new_core_eval': np.True_}
# 2025-10-15 12:41:40,316 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([46,  8, 37,  1, 19, 58, 44, 48, 50, 43, 23, 47,  3, 22, 27, 57, 59,
#        12, 54, 41, 42, 15, 17, 16,  0, 14, 34, 11, 31, 20, 18,  9, 35,  2,
#        28,  6, 51, 26,  4, 56, 25, 55, 33, 36, 24, 52, 29, 32, 40, 38, 30,
#        39, 49,  7, 13, 53,  5, 10, 45, 21]), 'epoch': 1, 'iter_in_epoch': 15, 'update': np.float64(3.5001390526115808), 'new_core_eval': np.True_}
# 2025-10-15 12:43:23,706 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([46,  8, 37,  1, 19, 58, 44, 48, 50, 43, 23, 47,  3, 22, 27, 57, 59,
#        12, 54, 41, 42, 15, 17, 16,  0, 14, 34, 11, 31, 20, 18,  9, 35,  2,
#        28,  6, 51, 26,  4, 56, 25, 55, 33, 36, 24, 52, 29, 32, 40, 38, 30,
#        39, 49,  7, 13, 53,  5, 10, 45, 21]), 'epoch': 1, 'iter_in_epoch': 16, 'update': np.float64(0.21878948630784545), 'new_core_eval': np.True_}
# 2025-10-15 12:45:03,353 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([46,  8, 37,  1, 19, 58, 44, 48, 50, 43, 23, 47,  3, 22, 27, 57, 59,
#        12, 54, 41, 42, 15, 17, 16,  0, 14, 34, 11, 31, 20, 18,  9, 35,  2,
#        28,  6, 51, 26,  4, 56, 25, 55, 33, 36, 24, 52, 29, 32, 40, 38, 30,
#        39, 49,  7, 13, 53,  5, 10, 45, 21]), 'epoch': 1, 'iter_in_epoch': 17, 'update': np.float64(1.5173451353464094), 'new_core_eval': np.True_}
# 2025-10-15 12:45:31,535 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([46,  8, 37,  1, 19, 58, 44, 48, 50, 43, 23, 47,  3, 22, 27, 57, 59,
#        12, 54, 41, 42, 15, 17, 16,  0, 14, 34, 11, 31, 20, 18,  9, 35,  2,
#        28,  6, 51, 26,  4, 56, 25, 55, 33, 36, 24, 52, 29, 32, 40, 38, 30,
#        39, 49,  7, 13, 53,  5, 10, 45, 21]), 'epoch': 1, 'iter_in_epoch': 18, 'update': np.float64(2.98369347063055), 'new_core_eval': np.True_}
# 2025-10-15 12:46:27,893 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([46,  8, 37,  1, 19, 58, 44, 48, 50, 43, 23, 47,  3, 22, 27, 57, 59,
#        12, 54, 41, 42, 15, 17, 16,  0, 14, 34, 11, 31, 20, 18,  9, 35,  2,
#        28,  6, 51, 26,  4, 56, 25, 55, 33, 36, 24, 52, 29, 32, 40, 38, 30,
#        39, 49,  7, 13, 53,  5, 10, 45, 21]), 'epoch': 1, 'iter_in_epoch': 19, 'update': np.float64(0.11317114523643901), 'new_core_eval': np.True_}
# 2025-10-15 12:46:54,024 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([46,  8, 37,  1, 19, 58, 44, 48, 50, 43, 23, 47,  3, 22, 27, 57, 59,
#        12, 54, 41, 42, 15, 17, 16,  0, 14, 34, 11, 31, 20, 18,  9, 35,  2,
#        28,  6, 51, 26,  4, 56, 25, 55, 33, 36, 24, 52, 29, 32, 40, 38, 30,
#        39, 49,  7, 13, 53,  5, 10, 45, 21]), 'epoch': 1, 'iter_in_epoch': 20, 'update': np.float64(2.5240789566643143), 'new_core_eval': np.True_}
# 2025-10-15 12:47:41,094 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([46,  8, 37,  1, 19, 58, 44, 48, 50, 43, 23, 47,  3, 22, 27, 57, 59,
#        12, 54, 41, 42, 15, 17, 16,  0, 14, 34, 11, 31, 20, 18,  9, 35,  2,
#        28,  6, 51, 26,  4, 56, 25, 55, 33, 36, 24, 52, 29, 32, 40, 38, 30,
#        39, 49,  7, 13, 53,  5, 10, 45, 21]), 'epoch': 1, 'iter_in_epoch': 21, 'update': np.float64(0.5843794956364645), 'new_core_eval': np.True_}
# 2025-10-15 12:48:06,134 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([46,  8, 37,  1, 19, 58, 44, 48, 50, 43, 23, 47,  3, 22, 27, 57, 59,
#        12, 54, 41, 42, 15, 17, 16,  0, 14, 34, 11, 31, 20, 18,  9, 35,  2,
#        28,  6, 51, 26,  4, 56, 25, 55, 33, 36, 24, 52, 29, 32, 40, 38, 30,
#        39, 49,  7, 13, 53,  5, 10, 45, 21]), 'epoch': 1, 'iter_in_epoch': 22, 'update': np.float64(3.466132199299165), 'new_core_eval': np.True_}
# 2025-10-15 12:48:31,987 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([46,  8, 37,  1, 19, 58, 44, 48, 50, 43, 23, 47,  3, 22, 27, 57, 59,
#        12, 54, 41, 42, 15, 17, 16,  0, 14, 34, 11, 31, 20, 18,  9, 35,  2,
#        28,  6, 51, 26,  4, 56, 25, 55, 33, 36, 24, 52, 29, 32, 40, 38, 30,
#        39, 49,  7, 13, 53,  5, 10, 45, 21]), 'epoch': 1, 'iter_in_epoch': 23, 'update': np.float64(-0.8750060027894322), 'new_core_eval': np.True_}
# 2025-10-15 12:49:26,561 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([46,  8, 37,  1, 19, 58, 44, 48, 50, 43, 23, 47,  3, 22, 27, 57, 59,
#        12, 54, 41, 42, 15, 17, 16,  0, 14, 34, 11, 31, 20, 18,  9, 35,  2,
#        28,  6, 51, 26,  4, 56, 25, 55, 33, 36, 24, 52, 29, 32, 40, 38, 30,
#        39, 49,  7, 13, 53,  5, 10, 45, 21]), 'epoch': 1, 'iter_in_epoch': 24, 'update': np.float64(-0.3453220782144225), 'new_core_eval': np.True_}
# 2025-10-15 12:49:53,963 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([46,  8, 37,  1, 19, 58, 44, 48, 50, 43, 23, 47,  3, 22, 27, 57, 59,
#        12, 54, 41, 42, 15, 17, 16,  0, 14, 34, 11, 31, 20, 18,  9, 35,  2,
#        28,  6, 51, 26,  4, 56, 25, 55, 33, 36, 24, 52, 29, 32, 40, 38, 30,
#        39, 49,  7, 13, 53,  5, 10, 45, 21]), 'epoch': 1, 'iter_in_epoch': 25, 'update': np.float64(3.881886695524133), 'new_core_eval': np.True_}
# 2025-10-15 12:50:19,431 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([46,  8, 37,  1, 19, 58, 44, 48, 50, 43, 23, 47,  3, 22, 27, 57, 59,
#        12, 54, 41, 42, 15, 17, 16,  0, 14, 34, 11, 31, 20, 18,  9, 35,  2,
#        28,  6, 51, 26,  4, 56, 25, 55, 33, 36, 24, 52, 29, 32, 40, 38, 30,
#        39, 49,  7, 13, 53,  5, 10, 45, 21]), 'epoch': 1, 'iter_in_epoch': 26, 'update': np.float64(1.7056787743351745), 'new_core_eval': np.True_}
# 2025-10-15 12:51:07,711 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([46,  8, 37,  1, 19, 58, 44, 48, 50, 43, 23, 47,  3, 22, 27, 57, 59,
#        12, 54, 41, 42, 15, 17, 16,  0, 14, 34, 11, 31, 20, 18,  9, 35,  2,
#        28,  6, 51, 26,  4, 56, 25, 55, 33, 36, 24, 52, 29, 32, 40, 38, 30,
#        39, 49,  7, 13, 53,  5, 10, 45, 21]), 'epoch': 1, 'iter_in_epoch': 27, 'update': np.float64(0.38416303898242155), 'new_core_eval': np.True_}
# 2025-10-15 12:51:33,848 INFO optimization_monitor: optimizer internal status: () {'idx_set': array([46,  8, 37,  1, 19, 58, 44, 48, 50, 43, 23, 47,  3, 22, 27, 57, 59,
#        12, 54, 41, 42, 15, 17, 16,  0, 14, 34, 11, 31, 20, 18,  9, 35,  2,
#        28,  6, 51, 26,  4, 56, 25, 55, 33, 36, 24, 52, 29, 32, 40, 38, 30,
#        39, 49,  7, 13, 53,  5, 10, 45, 21]), 'epoch': 1, 'iter_in_epoch': 28, 'update': np.float64(3.703676087000723), 'new_core_eval': np.True_}
# 2025-10-15 16:03:53,376 WARNING step_3: job d3njcp9fk6qs73e918s0 failed, retrying (10 remaining attempts)
# 2025-10-15 18:12:42,346 WARNING step_3: job d3nm6v34kkus739etbpg failed, retrying (9 remaining attempts)
# 2025-10-15 20:10:39,925 WARNING step_3: job d3no3bb4kkus739ev6ng failed, retrying (8 remaining attempts)
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~\anaconda3\envs\VQE_vanguard_womanium_wiser_2025\lib\site-packages\qiskit_ibm_runtime\api\session.py:328, in RetrySession.request(self, method, url, bare, **kwargs)
#     327     response = super().request(method, final_url, headers=headers, **kwargs)
# --> 328     response.raise_for_status()
#     329 except RequestException as ex:
#     330     # Wrap the requests exceptions into a IBM Q custom one, for
#     331     # compatibility.
#
# File ~\anaconda3\envs\VQE_vanguard_womanium_wiser_2025\lib\site-packages\requests\models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 401 Client Error: Unauthorized for url: https://quantum.cloud.ibm.com/api/v1/jobs/d3njcp9fk6qs73e918s0?exclude_params=true
#
# The above exception was the direct cause of the following exception:
#
# IBMNotAuthorizedError                     Traceback (most recent call last)
# File ~\Downloads\WISER_Optimization_VG-main\src\sbo\src\patterns\building_blocks\step_3.py:127, in HardwareExecutor.submit_job(self, theta, remaining_attempts)
#     126 try:
# --> 127     return job.result()
#     128 except QiskitError as error:
#
# File ~\anaconda3\envs\VQE_vanguard_womanium_wiser_2025\lib\site-packages\qiskit_ibm_runtime\runtime_job_v2.py:133, in RuntimeJobV2.result(self, timeout, decoder)
#     132 _decoder = decoder or self._final_result_decoder
# --> 133 self.wait_for_final_state(timeout=timeout)
#     134 if self._status == "ERROR":
#
# File ~\anaconda3\envs\VQE_vanguard_womanium_wiser_2025\lib\site-packages\qiskit_ibm_runtime\runtime_job_v2.py:252, in RuntimeJobV2.wait_for_final_state(self, timeout)
#     251         time.sleep(0.1)
# --> 252         status = self.status()
#     253 except futures.TimeoutError:
#
# File ~\anaconda3\envs\VQE_vanguard_womanium_wiser_2025\lib\site-packages\qiskit_ibm_runtime\runtime_job_v2.py:169, in RuntimeJobV2.status(self)
#     164 """Return the status of the job.
#     165
#     166 Returns:
#     167     Status of this job.
#     168 """
# --> 169 self._set_status_and_error_message()
#     170 return self._status
#
# File ~\anaconda3\envs\VQE_vanguard_womanium_wiser_2025\lib\site-packages\qiskit_ibm_runtime\base_runtime_job.py:212, in BaseRuntimeJob._set_status_and_error_message(self)
#     211 if self._status not in self.JOB_FINAL_STATES:
# --> 212     response = self._api_client.job_get(job_id=self.job_id())
#     213     self._set_status(response)
#
# File ~\anaconda3\envs\VQE_vanguard_womanium_wiser_2025\lib\site-packages\qiskit_ibm_runtime\api\clients\runtime.py:113, in RuntimeClient.job_get(self, job_id, exclude_params)
#     105 """Get job data.
#     106
#     107 Args:
#    (...)
#     111     JSON response.
#     112 """
# --> 113 response = self._api.program_job(job_id).get(exclude_params=exclude_params)
#     114 logger.debug("Runtime job get response: %s", response)
#
# File ~\anaconda3\envs\VQE_vanguard_womanium_wiser_2025\lib\site-packages\qiskit_ibm_runtime\api\rest\program_job.py:59, in ProgramJob.get(self, exclude_params)
#      57     payload["exclude_params"] = "true"
# ---> 59 return self.session.get(
#      60     self.get_url("self"), params=payload, headers=self._HEADER_JSON_ACCEPT
#      61 ).json(cls=RuntimeDecoder)
#
# File ~\anaconda3\envs\VQE_vanguard_womanium_wiser_2025\lib\site-packages\requests\sessions.py:602, in Session.get(self, url, **kwargs)
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File ~\anaconda3\envs\VQE_vanguard_womanium_wiser_2025\lib\site-packages\qiskit_ibm_runtime\api\session.py:349, in RetrySession.request(self, method, url, bare, **kwargs)
#     348 if status_code == 401:
# --> 349     raise IBMNotAuthorizedError(message) from ex
#     350 if status_code == 503:  # Planned maintenance outage
#
# IBMNotAuthorizedError: '401 Client Error: Unauthorized for url: https://quantum.cloud.ibm.com/api/v1/jobs/d3njcp9fk6qs73e918s0?exclude_params=true. {"errors":[{"code":1219,"message":"Error authenticating user.","solution":"Your IBM Quantum API token might be incorrect, expired, or revoked.\\nLog in to IBM Quantum Platform website and navigate to your account settings to generate a new API token.\\nUse QiskitRuntimeService.save_account(`APIKEY`, overwrite=True) to save the new API key, overwriting any outdated or incorrect credentials.","more_info":"https://cloud.ibm.com/apidocs/quantum-computing#error-handling"}],"trace":"04b08c6f-956f-4451-b880-20e3de958c01"}'
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# File ~\anaconda3\envs\VQE_vanguard_womanium_wiser_2025\lib\site-packages\qiskit_ibm_runtime\api\session.py:328, in RetrySession.request(self, method, url, bare, **kwargs)
#     327     response = super().request(method, final_url, headers=headers, **kwargs)
# --> 328     response.raise_for_status()
#     329 except RequestException as ex:
#     330     # Wrap the requests exceptions into a IBM Q custom one, for
#     331     # compatibility.
#
# File ~\anaconda3\envs\VQE_vanguard_womanium_wiser_2025\lib\site-packages\requests\models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 401 Client Error: Unauthorized for url: https://quantum.cloud.ibm.com/api/v1/jobs/d3nm6v34kkus739etbpg?exclude_params=true
#
# The above exception was the direct cause of the following exception:
#
# ...
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 11
#       8 max_time_seconds = 9 * 60  # 9 minutes to leave 1 min buffer
#      10 # execute the variational quantum optimization
# ---> 11 result = he.run()
#      13 # check if execution exceeded maximum time limit
#      14 if time.time() - start_time > max_time_seconds:
#
# File ~\Downloads\WISER_Optimization_VG-main\src\sbo\src\patterns\building_blocks\step_3.py:107, in HardwareExecutor.run(self)
#     105 def run(self) -> OptimizeResult:
#     106     try:
# --> 107         result = self._run_method()
#     108     except QiskitError as error:
#     109         # Return a partial result
#     110         result = OptimizeResult()
#
# File ~\Downloads\WISER_Optimization_VG-main\src\sbo\src\patterns\building_blocks\step_3.py:103, in HardwareExecutor._run_with_jobs(self)
#     101 def _run_with_jobs(self) -> OptimizeResult:
#     102     self.sampler = SamplerV2(mode=self.backend, options=self.sampler_options)
# --> 103     return self._run_with_sampler()
#
# File ~\Downloads\WISER_Optimization_VG-main\src\sbo\src\patterns\building_blocks\step_3.py:84, in HardwareExecutor._run_with_sampler(self)
#      82 def _run_with_sampler(self) -> OptimizeResult:
#      83     self.sampler.options.environment.job_tags = [self.run_id, f'{self.run_id}_{self.optimization_monitor.number_of_iterations()}']
# ---> 84     result = run_wrapper(
#      85         isa_ansatz=self.isa_ansatz,
#      86         optimizer_x0=self.optimizer_theta0,
#      87         optimization_fun=self.optimization_monitor.cost,
#      88         optimizer_args=(),
#      89         optimizer_method=self.optimizer_method,
#      90         optimizer_callback=self.optimization_monitor.callback,
#      91         solver_options=self.solver_options,
#      92     )
#      94     return result
#
# File ~\Downloads\WISER_Optimization_VG-main\src\sbo\src\optimizer\optimization_wrapper.py:62, in run(isa_ansatz, optimization_fun, optimizer_x0, optimizer_args, optimizer_method, optimizer_callback, solver_options)
#      59     method = nft_minimize
#      61 try:
# ---> 62     result = minimize(
#      63         fun=optimization_fun,
#      64         x0=theta_initial,
#      65         args=optimizer_args,
#      66         method=method,
#      67         jac=None,
#      68         hess=None,
#      69         hessp=None,
#      70         bounds=None,
#      71         constraints=(),
#      72         tol=None,
#      73         callback=optimizer_callback,
#      74         options=solver_options,
#      75     )
#      76 except RefValueReached as ex:
#      77     result = OptimizeResult()
#
# File ~\anaconda3\envs\VQE_vanguard_womanium_wiser_2025\lib\site-packages\scipy\optimize\_minimize.py:661, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     655         options.setdefault('barrier_tol', tol)
#     657 if meth == '_custom':
#     658     # custom method called before bounds and constraints are 'standardised'
#     659     # custom method should be able to accept whatever bounds/constraints
#     660     # are provided to it.
# --> 661     return method(fun, x0, args=args, jac=jac, hess=hess, hessp=hessp,
#     662                   bounds=bounds, constraints=constraints,
#     663                   callback=callback, **options)
#     665 constraints = standardize_constraints(constraints, x0, meth)
#     667 remove_vars = False
#
# File ~\Downloads\WISER_Optimization_VG-main\src\sbo\src\optimizer\nft.py:150, in nft_minimize(fun, x0, args, jac, hess, hessp, bounds, constraints, tol, callback, max_epoch, random_update, epoch_start, step_start, idx_set_start, **solver_options)
#     148 theta_1 = np.copy(theta)
#     149 theta_1[k] += np.pi / 2
# --> 150 val1 = fun(theta_1, *args)
#     151 nfev += 1
#     153 theta_2 = np.copy(theta)
#
# File ~\Downloads\WISER_Optimization_VG-main\src\sbo\src\optimizer\optimization_monitor.py:191, in OptimizationMonitor.cost(self, theta, *args)
#     189     print(f"cost: {self.calls_count:10d}", theta)
#     190 # the actual evaluation of the function
# --> 191 result = self._f(theta, *args)
#     193 self.list_calls_inp.append(theta)
#     194 self.list_calls_res.append(result)
#
# File ~\Downloads\WISER_Optimization_VG-main\src\sbo\src\patterns\building_blocks\step_3.py:151, in HardwareExecutor.calc_aggregate_objective(self, theta)
#     149 self.optimization_monitor.objective_monitor.list_job_cnt = []
#     150 self.optimization_monitor.objective_monitor.list_job_fx = []
# --> 151 result = self.submit_job(theta, self.max_retries)
#     153 aggr_obj = self._sampler_result_to_aggregate_objective(result)
#     154 return aggr_obj
#
# File ~\Downloads\WISER_Optimization_VG-main\src\sbo\src\patterns\building_blocks\step_3.py:131, in HardwareExecutor.submit_job(self, theta, remaining_attempts)
#     129 if remaining_attempts > 0:
#     130     LOGGER.warning('job %s failed, retrying (%d remaining attempts)', job_id, remaining_attempts)
# --> 131     return self.submit_job(theta, remaining_attempts=remaining_attempts-1)
#     132 else:
#     133     raise error
#
# File ~\Downloads\WISER_Optimization_VG-main\src\sbo\src\patterns\building_blocks\step_3.py:131, in HardwareExecutor.submit_job(self, theta, remaining_attempts)
#     129 if remaining_attempts > 0:
#     130     LOGGER.warning('job %s failed, retrying (%d remaining attempts)', job_id, remaining_attempts)
# --> 131     return self.submit_job(theta, remaining_attempts=remaining_attempts-1)
#     132 else:
#     133     raise error
#
# File ~\Downloads\WISER_Optimization_VG-main\src\sbo\src\patterns\building_blocks\step_3.py:131, in HardwareExecutor.submit_job(self, theta, remaining_attempts)
#     129 if remaining_attempts > 0:
#     130     LOGGER.warning('job %s failed, retrying (%d remaining attempts)', job_id, remaining_attempts)
# --> 131     return self.submit_job(theta, remaining_attempts=remaining_attempts-1)
#     132 else:
#     133     raise error
#
# File ~\Downloads\WISER_Optimization_VG-main\src\sbo\src\patterns\building_blocks\step_3.py:127, in HardwareExecutor.submit_job(self, theta, remaining_attempts)
#     125 self.job_ids.append(job_id)
#     126 try:
# --> 127     return job.result()
#     128 except QiskitError as error:
#     129     if remaining_attempts > 0:
#
# File ~\anaconda3\envs\VQE_vanguard_womanium_wiser_2025\lib\site-packages\qiskit_ibm_runtime\runtime_job_v2.py:133, in RuntimeJobV2.result(self, timeout, decoder)
#     118 """Return the results of the job.
#     119
#     120 Args:
#    (...)
#     130     RuntimeInvalidStateError: If the job was cancelled, and attempting to retrieve result.
#     131 """
#     132 _decoder = decoder or self._final_result_decoder
# --> 133 self.wait_for_final_state(timeout=timeout)
#     134 if self._status == "ERROR":
#     135     error_message = self._reason if self._reason else self._error_message
#
# File ~\anaconda3\envs\VQE_vanguard_womanium_wiser_2025\lib\site-packages\qiskit_ibm_runtime\runtime_job_v2.py:252, in RuntimeJobV2.wait_for_final_state(self, timeout)
#     248             raise RuntimeJobTimeoutError(
#     249                 f"Timed out waiting for job to complete after {timeout} secs."
#     250             )
#     251         time.sleep(0.1)
# --> 252         status = self.status()
#     253 except futures.TimeoutError:
#     254     raise RuntimeJobTimeoutError(
#     255         f"Timed out waiting for job to complete after {timeout} secs."
#     256     )
#
# File ~\anaconda3\envs\VQE_vanguard_womanium_wiser_2025\lib\site-packages\qiskit_ibm_runtime\runtime_job_v2.py:169, in RuntimeJobV2.status(self)
#     163 def status(self) -> JobStatus:
#     164     """Return the status of the job.
#     165
#     166     Returns:
#     167         Status of this job.
#     168     """
# --> 169     self._set_status_and_error_message()
#     170     return self._status
#
# File ~\anaconda3\envs\VQE_vanguard_womanium_wiser_2025\lib\site-packages\qiskit_ibm_runtime\base_runtime_job.py:212, in BaseRuntimeJob._set_status_and_error_message(self)
#     210 """Fetch and set status and error message."""
#     211 if self._status not in self.JOB_FINAL_STATES:
# --> 212     response = self._api_client.job_get(job_id=self.job_id())
#     213     self._set_status(response)
#     214     self._set_error_message(response)
#
# File ~\anaconda3\envs\VQE_vanguard_womanium_wiser_2025\lib\site-packages\qiskit_ibm_runtime\api\clients\runtime.py:113, in RuntimeClient.job_get(self, job_id, exclude_params)
#     104 def job_get(self, job_id: str, exclude_params: bool = True) -> Dict:
#     105     """Get job data.
#     106
#     107     Args:
#    (...)
#     111         JSON response.
#     112     """
# --> 113     response = self._api.program_job(job_id).get(exclude_params=exclude_params)
#     114     logger.debug("Runtime job get response: %s", response)
#     115     return response
#
# File ~\anaconda3\envs\VQE_vanguard_womanium_wiser_2025\lib\site-packages\qiskit_ibm_runtime\api\rest\program_job.py:59, in ProgramJob.get(self, exclude_params)
#      56 if exclude_params:
#      57     payload["exclude_params"] = "true"
# ---> 59 return self.session.get(
#      60     self.get_url("self"), params=payload, headers=self._HEADER_JSON_ACCEPT
#      61 ).json(cls=RuntimeDecoder)
#
# File ~\anaconda3\envs\VQE_vanguard_womanium_wiser_2025\lib\site-packages\requests\sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File ~\anaconda3\envs\VQE_vanguard_womanium_wiser_2025\lib\site-packages\qiskit_ibm_runtime\api\session.py:327, in RetrySession.request(self, method, url, bare, **kwargs)
#     325 try:
#     326     self._log_request_info(final_url, method, kwargs)
# --> 327     response = super().request(method, final_url, headers=headers, **kwargs)
#     328     response.raise_for_status()
#     329 except RequestException as ex:
#     330     # Wrap the requests exceptions into a IBM Q custom one, for
#     331     # compatibility.
#
# File ~\anaconda3\envs\VQE_vanguard_womanium_wiser_2025\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\anaconda3\envs\VQE_vanguard_womanium_wiser_2025\lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\anaconda3\envs\VQE_vanguard_womanium_wiser_2025\lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~\anaconda3\envs\VQE_vanguard_womanium_wiser_2025\lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~\anaconda3\envs\VQE_vanguard_womanium_wiser_2025\lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~\anaconda3\envs\VQE_vanguard_womanium_wiser_2025\lib\site-packages\urllib3\connection.py:565, in HTTPConnection.getresponse(self)
#     562 _shutdown = getattr(self.sock, "shutdown", None)
#     564 # Get the response from http.client.HTTPConnection
# --> 565 httplib_response = super().getresponse()
#     567 try:
#     568     assert_header_parsing(httplib_response.msg)
#
# File ~\anaconda3\envs\VQE_vanguard_womanium_wiser_2025\lib\http\client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File ~\anaconda3\envs\VQE_vanguard_womanium_wiser_2025\lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~\anaconda3\envs\VQE_vanguard_womanium_wiser_2025\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~\anaconda3\envs\VQE_vanguard_womanium_wiser_2025\lib\socket.py:717, in SocketIO.readinto(self, b)
#     715 while True:
#     716     try:
# --> 717         return self._sock.recv_into(b)
#     718     except timeout:
#     719         self._timeout_occurred = True
#
# File ~\anaconda3\envs\VQE_vanguard_womanium_wiser_2025\lib\ssl.py:1307, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1303     if flags != 0:
#    1304         raise ValueError(
#    1305           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1306           self.__class__)
# -> 1307     return self.read(nbytes, buffer)
#    1308 else:
#    1309     return super().recv_into(buffer, nbytes, flags)
#
# File ~\anaconda3\envs\VQE_vanguard_womanium_wiser_2025\lib\ssl.py:1163, in SSLSocket.read(self, len, buffer)
#    1161 try:
#    1162     if buffer is not None:
# -> 1163         return self._sslobj.read(len, buffer)
#    1164     else:
#    1165         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Post-Processing: Local Search
#
# The local search phase applies classical optimization to refine the best quantum solution.
#
# ## Local Search Configuration
#
# The `repeated_local_search_general()` function takes these parameters:
# - **x**: Quantum best solution
# - **val**: Quantum best objective value
# - **func**: Numba-compatible objective function
# - **options**: Configuration dictionary
#
# The first two parameters are already obtained, while the remaining two must be set prior to running local search.
#
# ### Func: Numba-Compatible Objective Function
#
# Since local search uses numba-compiled code for speed, the CPLEX-parsable LP file must be converted into a docplex model. This model is then passed to the `model_to_obj()` function to generate a numba-compatible objective function. The previously loaded `quadratic_problem` (created from the same LP file) cannot be used because it produces a `QuadraticProgram` object, which is not compatible with the `model_to_obj()` function, as it expects a docplex model.
#
# - LP file → QuadraticProgram → objective function is **not numba-compatible** → usable for quantum phase, **not usable for local search**
# - LP file → docplex model → objective function is **numba-compatible** → **usable for local search**
#
# The local search objective function is built from the full 31-variable LP file but automatically handles variable-length input arrays. NumPy's broadcasting behavior allows the function to work with reduced solutions by treating missing elements as zeros, ensuring compatibility between the reduced quantum solution and the full-problem objective function.

# %%
# create a docplex Model object
docplex_model = docplex.mp.model_reader.ModelReader.read(lp_file_path)

# decorate the objective function to be numba compatible
numba_compatiable_objective_function = model_to_obj(docplex_model)
# Out:
# 31 15

# %% [markdown]
# ### Options: Configuration Dictionary
#
# - **num_bitflips**: Number of bits to flip per iteration (set to 1 for fine-tuning).
# - **maxepoch**: Maximum number of local search epochs (set to 8). This complements the 2 epochs from the quantum phase, resulting in a total of 10 epochs in the hybrid approach.
# - **maxfevals_per_variable**: Maximum number of times the objective function is evaluated per variable during one epoch of local search (set to 3 for a balance between solution quality and speed). For example, with 10 variables and this parameter set to 3, the algorithm performs up to 30 evaluations per epoch.
# - **refval**: Must be a float (not None) to avoid typing errors. Local search stops when the current value is close to or better than this reference value (set to infinity to disable early stopping).

# %%
# create doe_localsearch pattern
doe_ls = {
    'local_search_doe': 'balance',
    'local_search_num_bitflips': 1,
    'local_search_maxiter': None,
    'local_search_maxepoch': 8,  # -- MODIFY HERE --
    'local_search_maxfevals_per_variable': 3
}

# calculate maxfevals based on number of variables
if 'local_search_maxfevals_per_variable' in doe_ls:
    doe_ls['local_search_maxfevals'] = len(best_x_quantum) * doe_ls.pop('local_search_maxfevals_per_variable')

# define refval # cannot be none
refval = float('inf')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 12
#      10 # calculate maxfevals based on number of variables
#      11 if 'local_search_maxfevals_per_variable' in doe_ls:
# ---> 12     doe_ls['local_search_maxfevals'] = len(best_x_quantum) * doe_ls.pop('local_search_maxfevals_per_variable')
#      14 # define refval # cannot be none
#      15 refval = float('inf')
#
# NameError: name 'best_x_quantum' is not defined

# %%
# apply local search post-processing
print("Starting local search refinement...")

# record start time for performance measurement
local_search_start = time.time()

# call local search
best_x_hybrid, best_fx_hybrid, num_epochs, num_fevals, vals = repeated_local_search_general(
    x=best_x_quantum,
    val=best_fx_quantum,
    func=numba_compatiable_objective_function,
    options=doe_ls | {'refval': refval}
)

# create result dictionary to match postprocess format
refined_solution = {
    'status': 'success',
    'objective': float(best_fx_hybrid),
    'solution': best_x_hybrid,
    'execution_callback_count': he.optimization_monitor.callback_count,
    'execution_results': he.optimization_monitor.list_callback_res,
    'execution_f_value_best': he.optimization_monitor.list_callback_monitor_best,
    'message': "Local search completed successfully"
}

# record end time and calculate total local search time
local_search_end = time.time()
print(f"Local search completed in {local_search_end - local_search_start:.2f} seconds")
print(f"Hybrid best solution: {best_x_hybrid}")
print(f"Hybrid best objective value: {best_fx_hybrid}")
print(f"Improvement: {best_fx_quantum - best_fx_hybrid:.6f}")
# Out:
# Starting local search refinement...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 9
#       5 local_search_start = time.time()
#       7 # call local search
#       8 best_x_hybrid, best_fx_hybrid, num_epochs, num_fevals, vals = repeated_local_search_general(
# ----> 9     x=best_x_quantum,
#      10     val=best_fx_quantum,
#      11     func=numba_compatiable_objective_function,
#      12     options=doe_ls | {'refval': refval}
#      13 )
#      15 # create result dictionary to match postprocess format
#      16 refined_solution = {
#      17     'status': 'success',
#      18     'objective': float(best_fx_hybrid),
#    (...)
#      23     'message': "Local search completed successfully"
#      24 }
#
# NameError: name 'best_x_quantum' is not defined

# %% [markdown]
# ## Result
#
# The experiment is saved as a pickle file containing all the necessary data for analysis, reproducibility, debugging, and research. The saved data includes optimization results, convergence data, performance metrics, configuration settings, and experiment metadata.
#
# The experiment object includes:
# - Configuration: Ansatz, parameters, optimizer settings, CVaR alpha, local search settings
# - Performance: Execution time, iterations, convergence behavior
# - Results: Best solution, objective value, relative gap
# - Monitoring: Parameter evolution, objective function calls, optimization trajectory
# - Hardware: Backend, shots, classical hardware specs

# %%
# set path
experiment_path = Path(str(ROOT) + f"/project/exp_heavyweight_hybrid_qpu_reduced_{num_vars}_bonds.pkl")

# %%
# create an Experiment object from the hybrid results
# use from_step3()
experiment = Experiment.from_step3(
    experiment_id="heavyweight_hybrid_run",
    ansatz="TwoLocal",
    ansatz_params={'reps': 2, 'entanglement': 'full'},
    theta_initial="piby3",
    device=backend.name,  # use actual IBM Quantum device name instead
    optimizer="nft",
    alpha=alpha,
    theta_threshold=None,
    lp_file="31bonds/docplex-bin-avgonly-nocplexvars.lp",
    shots=shots,
    refx=None,      # set this for a reference solution
    refvalue=None,  # set this for a reference value
    classical_hw=Experiment.get_current_classical_hw(),
    step3_time=end_time - start_time,
    step3_job_ids=he.job_ids,
    result=result,
    optimization_monitor=he.optimization_monitor
)

# override step4 fields that were set to None in from_step3()
experiment.step4_time = local_search_end - local_search_start
experiment.step4_result_best_x = best_x_hybrid
experiment.step4_result_best_fx = best_fx_hybrid
experiment.step4_iter_best_fx = refined_solution.get('execution_f_value_best', [])

# save the experiment for analysis
experiment_path.parent.mkdir(parents=True, exist_ok=True)
with open(experiment_path, 'wb') as f:
    pickle.dump(asdict(experiment), f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 17
#       1 # create an Experiment object from the hybrid results
#       2 # use from_step3()
#       3 experiment = Experiment.from_step3(
#       4     experiment_id="heavyweight_hybrid_run",
#       5     ansatz="TwoLocal",
#       6     ansatz_params={'reps': 2, 'entanglement': 'full'},
#       7     theta_initial="piby3",
#       8     device=backend.name,  # use actual IBM Quantum device name instead
#       9     optimizer="nft",
#      10     alpha=alpha,
#      11     theta_threshold=None,
#      12     lp_file="31bonds/docplex-bin-avgonly-nocplexvars.lp",
#      13     shots=shots,
#      14     refx=None,      # set this for a reference solution
#      15     refvalue=None,  # set this for a reference value
#      16     classical_hw=Experiment.get_current_classical_hw(),
# ---> 17     step3_time=end_time - start_time,
#      18     step3_job_ids=he.job_ids,
#      19     result=result,
#      20     optimization_monitor=he.optimization_monitor
#      21 )
#      23 # override step4 fields that were set to None in from_step3()
#      24 experiment.step4_time = local_search_end - local_search_start
#
# NameError: name 'end_time' is not defined
